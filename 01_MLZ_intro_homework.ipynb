# %% [markdown]
# <a href="https://colab.research.google.com/github/JustinShawAcademy/data-science/blob/main/01_MLZ_intro_homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 01-MLZ-intro-homework
# This is homework that is is a part of 2025 Machine Learning Zoomcamp.
#
# More on it can be found this [blog](https://datatalks.club/blog/guide-to-free-online-courses-at-datatalks-club.html#machine-learning-zoomcamp) and their [github](https://github.com/DataTalksClub/machine-learning-zoomcamp)

# %% [markdown]
# ## Q1. Pandas version

# %%
import pandas as pd
pd.__version__
# Out:
# '2.2.2'

# %% [markdown]
# ## Q2. Records count
# How many records are in the dataset?

# %%
df = pd.read_csv("https://raw.githubusercontent.com/alexeygrigorev/datasets/master/car_fuel_efficiency.csv")
df
# Out:
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                     170            3.0       159.0     3413.433759
# 1                     130            5.0        97.0     3149.664934
# 2                     170            NaN        78.0     3079.038997
# 3                     220            4.0         NaN     2542.392402
# 4                     210            1.0       140.0     3460.870990
# ...                   ...            ...         ...             ...
# 9699                  140            5.0       164.0     2981.107371
# 9700                  180            NaN       154.0     2439.525729
# 9701                  220            2.0       138.0     2583.471318
# 9702                  230            4.0       177.0     2905.527390
# 9703                  270            3.0       140.0     2908.043477
#
#       acceleration  model_year  origin fuel_type         drivetrain  \
# 0             17.7        2003  Europe  Gasoline    All-wheel drive
# ...

# %% [markdown]
# ## Q3. Fuel types
# How many fuel types are presented in the dataset?

# %%
df['fuel_type'].unique(), len(df['fuel_type'].unique())
# Out:
# (array(['Gasoline', 'Diesel'], dtype=object), 2)

# %% [markdown]
# ## Q4. Missing values
# How many columns in the dataset have missing values?

# %%
df.columns[df.isnull().any()], len(df.columns[df.isnull().any()])
# Out:
# (Index(['num_cylinders', 'horsepower', 'acceleration', 'num_doors'], dtype='object'),
#  4)

# %% [markdown]
# ## Q5. Max fuel efficiency
# What's the maximum fuel efficiency of cars from Asia?

# %%
asia_cars = df[df['origin'] == 'Asia']
max_fuel_efficiency_asia = asia_cars['fuel_efficiency_mpg'].max()
print(max_fuel_efficiency_asia)
# Out:
# 23.759122836520497

# %% [markdown]
# ## Q6. Median value of horsepower
# 1. Find the median value of horsepower column in the dataset.
# 2. Next, calculate the most frequent value of the same horsepower column.
# 3. Use fillna method to fill the missing values in horsepower column with the most frequent value from the previous step.
# 4. Now, calculate the median value of horsepower once again.
# Has it changed?
#
# - Yes, it increased
# - Yes, it decreased
# - No

# %%
df.head()
# Out:
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                  170            3.0       159.0     3413.433759
# 1                  130            5.0        97.0     3149.664934
# 2                  170            NaN        78.0     3079.038997
# 3                  220            4.0         NaN     2542.392402
# 4                  210            1.0       140.0     3460.870990
#
#    acceleration  model_year  origin fuel_type         drivetrain  num_doors  \
# 0          17.7        2003  Europe  Gasoline    All-wheel drive        0.0
# 1          17.8        2007     USA  Gasoline  Front-wheel drive        0.0
# 2          15.1        2018  Europe  Gasoline  Front-wheel drive        0.0
# 3          20.2        2009     USA    Diesel    All-wheel drive        2.0
# 4          14.4        2009  Europe  Gasoline    All-wheel drive        2.0
#
#    fuel_efficiency_mpg
# 0            13.231729
# 1            13.688217
# 2            14.246341
# ...

# %%
# 1. Find the median value of horsepower column in the dataset.
df['horsepower'].median()
# Out:
# 149.0

# %%
# 2. Next, calculate the most frequent value of the same horsepower column.
most_frequent_horsepower = df['horsepower'].value_counts().idxmax()
most_frequent_horsepower
# Out:
# np.float64(152.0)

# %%
# 3. Use fillna method to fill the missing values in horsepower column with the most frequent value from the previous step.
df['horsepower'] = df['horsepower'].fillna(most_frequent_horsepower)

# %%
# 4. Now, calculate the median value of horsepower once again.
new_median_horsepower = df['horsepower'].median()
print(new_median_horsepower)
# Out:
# 152.0

# %% [markdown]
# ## Q7. Sum of weights
# 1. Select all the cars from Asia
# 2. Select only columns vehicle_weight and model_year
# 3. Select the first 7 values
# 4. Get the underlying NumPy array. Let's call it X.
# 5. Compute matrix-matrix multiplication between the transpose of X and X. To get the transpose, use X.T. Let's call the result XTX.
# Invert XTX.
# 6. Create an array y with values [1100, 1300, 800, 900, 1000, 1100, 1200].
# Multiply the inverse of XTX with the transpose of X, and then multiply the result by y. Call the result w.
# 7. What's the sum of all the elements of the result?
# > Note: Here, linear regression was just implemented. More about it about it in the next lesson.

# %%
# 1. Select all the cars from Asia
asia_df = df[df['origin'] == 'Asia']
asia_df
# Out:
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 8                     250            1.0       174.0     2714.219310
# 12                    320            5.0       145.0     2783.868974
# 14                    200            6.0       160.0     3582.687368
# 20                    150            3.0       197.0     2231.808142
# 21                    160            4.0       133.0     2659.431451
# ...                   ...            ...         ...             ...
# 9688                  260            4.0       152.0     3948.404625
# 9692                  180            3.0       188.0     3680.341381
# 9693                  280            2.0       148.0     2545.070139
# 9698                  180            1.0       131.0     3107.427820
# 9703                  270            3.0       140.0     2908.043477
#
#       acceleration  model_year origin fuel_type         drivetrain  num_doors  \
# ...

# %%
# 2. Select only columns vehicle_weight and model_year
asia_df = asia_df[['vehicle_weight', 'model_year']]
asia_df
# Out:
#       vehicle_weight  model_year
# 8        2714.219310        2016
# 12       2783.868974        2010
# 14       3582.687368        2007
# 20       2231.808142        2011
# 21       2659.431451        2016
# ...              ...         ...
# 9688     3948.404625        2018
# 9692     3680.341381        2016
# 9693     2545.070139        2012
# 9698     3107.427820        2005
# 9703     2908.043477        2005
#
# [3247 rows x 2 columns]

# %%
# 3. Select the first 7 values
asia_df = asia_df[:7]
asia_df
# Out:
#     vehicle_weight  model_year
# 8      2714.219310        2016
# 12     2783.868974        2010
# 14     3582.687368        2007
# 20     2231.808142        2011
# 21     2659.431451        2016
# 34     2844.227534        2014
# 38     3761.994038        2019

# %%
# 4. Get the underlying NumPy array. Let's call it X.
X = asia_df.values
print(X)
# Out:
# [[2714.21930965 2016.        ]
#  [2783.86897424 2010.        ]
#  [3582.68736772 2007.        ]
#  [2231.8081416  2011.        ]
#  [2659.43145076 2016.        ]
#  [2844.22753389 2014.        ]
#  [3761.99403819 2019.        ]]

# %%
X.shape
# Out:
# (7, 2)

# %%
# 5. Compute matrix-matrix multiplication between the transpose of X and X. To get the transpose, use X.T. Let's call the result XTX.
XTX = X.T @ X # (2, 7) @ (7, 2) = (2, 2)

# Invert XTX.
XTX_inv = np.linalg.inv(XTX)

print("XTX:")
print(XTX)
print("\nXTX_inv:")
print(XTX_inv)
# Out:
# XTX:
# [[62248334.33150762 41431216.5073268 ]
#  [41431216.5073268  28373339.        ]]
#
# XTX_inv:
# [[ 5.71497081e-07 -8.34509443e-07]
#  [-8.34509443e-07  1.25380877e-06]]

# %%
# 6. Create an array y with values [1100, 1300, 800, 900, 1000, 1100, 1200].
y = np.array([1100, 1300, 800, 900, 1000, 1100, 1200])

# Multiply the inverse of XTX with the transpose of X, and then multiply the result by y. Call the result w.
w = XTX_inv @ X.T @ y # (2, 2) @ (2, 7) @ (7, 1) = (2, 1)
w
# Out:
# array([0.01386421, 0.5049067 ])

# %%
# 7. What's the sum of all the elements of the result?
sum_of_w = w.sum()

print("w:")
print(w)
print("\nSum of elements in w:")
print(sum_of_w)
# Out:
# w:
# [0.01386421 0.5049067 ]
#
# Sum of elements in w:
# 0.5187709081074016
